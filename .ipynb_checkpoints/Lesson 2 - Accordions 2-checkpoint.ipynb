# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
import fastai
fastai.__version__
#!ls -alt
# Out:
# '1.0.19'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Sun Nov  4 18:50:07 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.73       Driver Version: 410.73       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Quadro M4000        Off  | 00000000:00:05.0 Off |                  N/A |
# | 47%   39C    P0    44W / 120W |     11MiB /  8126MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'accordion'
file = 'accordion.csv'

# %%
folder = 'bayan'
file = 'bayan.csv'

# %%
folder = 'concertina'
file = 'concertina.csv'

# %%
folder = 'bandoneon'
file = 'bandoneon.csv'

# %% [markdown]
# You will need to run this line once per each category.

# %%
path = Path('data/Lesson 2 Accordion/bandoneon')
dest = path
dest.mkdir(parents=True, exist_ok=True)

# %%
path = Path('data/Lesson 2 Accordion')
path
# Out:
# PosixPath('data/Lesson 2 Accordion')

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['accordion','bayan','concertina','bandoneon']

# %%
path = Path('data/Lesson 2 Accordion')
for x in classes:
  print('class: ' + x)
  folder = x
  print('folder: ' + folder)
  file = x + '.csv'
  dest = path/folder
  download_images(dest/file, dest, max_pics=200)
# Out:
# class: accordion
# folder: accordion
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:26<00:00]
#     </div>
# Error http://www.long-mcquade.com/files/20193/lg_Bravo%20II%2048%20black.jpg 'content-length'
# Error https://www.oxfordlearnersdictionaries.com/media/english/fullsize/a/acc/accor/accordion.jpg ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# Error https://www.cmuse.org/wp-content/uploads/2018/08/famous-accordion-player.jpg 'content-length'
# Error http://www.gulfmusicsales.com/gulfmusicsales.com/Art/Accordions/Alacran/AL3112/AL3112_RDP.png 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=118875051468820 'content-length'
# Error http://www.macsaccordion.com/SiteResource/Site_105498/Customize/Image/IMG_0435_2.JPG 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=190005781064290 'content-length'
# Error http://www.macsaccordion.com/SiteResource/Site_105498/Customize/Image/IMG_0439.JPG 'content-length'
# class: bayan
# folder: bayan
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 04:14<00:00]
#     </div>
# Error https://fscomps.fotosearch.com/compc/CSP/CSP990/old-bayan-musical-instrument-as-picture__k10219957.jpg 'content-length'
# Error https://c8.alamy.com/comp/MFGN6X/musical-instrument-classical-bayan-accordion-corporate-identity-sketch-vector-illustration-MFGN6X.jpg 'content-length'
# Error http://thumb3.zeppy.io/d/l400/pict/301520061331/ukrainian-button-accordion-bayan-harmonika-garmon-2-rows-25-x-25-366 'content-length'
# Error https://i1.sndcdn.com/artworks-000116022987-359v9d-t500x500.jpg 'content-length'
# Error https://flypaper.soundfly.com/wp-content/uploads/2016/09/Multiple-reeds-1024x611.jpg 'content-length'
# Error https://l450v.alamy.com/450v/my2bgg/old-musical-instrument-bayan-accordion-isolated-on-white-background-my2bgg.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1875992732464754 'content-length'
# Error https://c8.alamy.com/comp/D2T83M/vintage-1930s-black-accordion-isolated-on-white-background-D2T83M.jpg 'content-length'
# Error https://images1.americanlisted.com/nlarge/chromatic-accordion-russian-bayan-450-spokane-americanlisted_29101757.jpg 'content-length'
# Error http://grosircelanahernia.com/wp-content/uploads/2018/09/piano-accordion-keyboard-layout-best-are-you-my-type-accordions-similar-but-different-of-piano-accordion-keyboard-layout.jpg 'content-length'
# Error http://thumb4.zeppy.io/d/l400/pict/273487773085/russian-button-accordion-melody-ussr-bayan-100-bass-registers-2-acordeon-case 'content-length'
# Error https://l450v.alamy.com/450v/km1y34/old-musical-instrument-russian-bayan-button-accordion-close-up-km1y34.jpg 'content-length'
# Error http://www.alwaysfaith-music.com/uploads/allimg/170110/1-1F110164200-lp.jpg HTTPConnectionPool(host='www.alwaysfaith-music.com', port=80): Max retries exceeded with url: /uploads/allimg/170110/1-1F110164200-lp.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f031d781710>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=156412231089488 'content-length'
# Error http://grosircelanahernia.com/wp-content/uploads/2018/09/accordion-keyboard-layout-good-zonta-zb16-120-bass-converter-bayan-accordion-free-the-reed-of-accordion-keyboard-layout.jpg 'content-length'
# Error http://bayanrussianaccordian.weebly.com/uploads/5/9/9/7/59977451/9861030_orig.jpg HTTPConnectionPool(host='bayanrussianaccordian.weebly.com', port=80): Max retries exceeded with url: /uploads/5/9/9/7/59977451/9861030_orig.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f031d78e7b8>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# class: concertina
# folder: concertina
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:15<00:00]
#     </div>
# Error https://c8.alamy.com/comp/ERFE3F/inst-keyboard-accordion-concertina-being-played-ERFE3F.jpg 'content-length'
# Error https://images-cdn.auctionmobility.com/is3/auctionmobility-static/0rDs-1-6T69G//161.4.jpg?maxwidth=1000&maxheight=1000 'content-length'
# Error http://accordioncentre.com/acb/wp-content/uploads/2018/01/Hohner-D40-20-Key-Anglo-Concertina.jpg ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Error https://eagle-images.imgix.net/general/L/squeezebox-buying-guide.jpg?auto=format&fit=max&w=320&h=213 'content-length'
# Error https://c8.alamy.com/comp/PA3BY7/concertina-183137-london-england-united-kingdom-british-rosewood-nickel-silver-leather-paper-ivory-tortoiseshell-case-of-mahogany-overall-76-x-146-cm-3-x-5-34-in-aerophone-free-reed-concertina-accordion-charles-wheatstone-18021875-PA3BY7.jpg 'content-length'
# Error http://accordioncentre.com/acb/wp-content/uploads/2018/01/Hohner-Club-II-B-Melodeon.jpg ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Error https://coursehorse.imgix.net/images/course/21/main/1-Concertina%20Beginners.jpg?auto=format%2Cenhance&crop=entropy&fit=crop&h=630&ixlib=php-1.2.1&q=90&w=1200 'content-length'
# Error http://accordioncentre.com/acb/wp-content/uploads/2018/03/DSC_0230gallery.jpg ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Error http://www.saltarelle.com/sites/default/files/bourroche_or_0.jpg 'content-length'
# Error https://c8.alamy.com/comp/B3YPT2/music-instruments-keyboard-instruments-accordion-the-lachenal-england-B3YPT2.jpg 'content-length'
# Error https://collectionapi.metmuseum.org/api/collection/v1/iiif/504258/1023062/restricted 'content-length'
# Error https://cdn2.bigcommerce.com/server5000/893ij2w/products/636/images/4375/IMG-1847__36574.1521234492.1280.1280.jpg?c=2 'content-length'
# Error http://www.concertinaconnection.com/clover%20natural.jpg 'content-length'
# Error http://accordioncentre.com/acb/wp-content/uploads/2018/03/DSC_0244galleryx.jpg ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# class: bandoneon
# folder: bandoneon
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 04:27<00:00]
#     </div>
# Error https://fscomps.fotosearch.com/compc/CSP/CSP672/bandoneon-accordion-icon-cartoon-style-clip-art__k36580157.jpg 'content-length'
# Error http://bellows-works-tokyo.com/images/top-make.jpg 'content-length'
# Error https://media.npr.org/assets/img/2011/07/19/astor-6b0ddb8a96b305b123f2198b969e4639e031bc8b-s800-c85.jpg 'content-length'
# Error http://flypaper.soundfly.com/wp-content/uploads/2016/09/accordion-for-facebook.jpg 'content-length'
# Error https://flypaper.soundfly.com/wp-content/uploads/2016/09/Zonta-ZB16-converter-bayan-accordion-front-of-bellows-1024x662.jpg 'content-length'
# Error http://www.saltarelle.com/sites/default/files/bourroche_or_0.jpg 'content-length'
# Error x-raw-image:///0c328c17a98139a74f891172dfcb05d50d83dc88c1df8f1f52028824f55b5dc5 No connection adapters were found for 'x-raw-image:///0c328c17a98139a74f891172dfcb05d50d83dc88c1df8f1f52028824f55b5dc5'
# Error https://flypaper.soundfly.com/wp-content/uploads/2016/09/15286438884_d0b9ea9817_k-273x300.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=10152824227832981 'content-length'
# Error https://c8.alamy.com/comp/B022BR/man-playing-the-accordion-on-the-ferry-en-route-to-the-faroe-islands-B022BR.jpg 'content-length'
# Error http://l7.alamy.com/zooms/b02d7e0e16d64652811fa2adb0e76898/traditional-tango-musical-instrument-the-bandoneon-cerdt4.jpg 'content-length'
# Error http://www.bandoneon-international.org/wp-content/uploads/2018/05/cropped-bandowshop.jpg ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Error https://roxys.com/wp-content/uploads/2018/01/Planet-Accordion-PAM525.7.jpg 'content-length'
# Error http://www.musicantic.eu/pages/images-shop/2108_1.jpg HTTPConnectionPool(host='www.musicantic.eu', port=80): Max retries exceeded with url: /pages/images-shop/2108_1.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f031d781128>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# Error http://accordeonworld.weebly.com/uploads/1/8/7/3/18731590/1722057.jpg?369 HTTPConnectionPool(host='accordeonworld.weebly.com', port=80): Max retries exceeded with url: /uploads/1/8/7/3/18731590/1722057.jpg?369 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f031d78e4a8>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# Error http://accordeonworld.weebly.com/uploads/1/8/7/3/18731590/3778695.jpg?304 HTTPConnectionPool(host='accordeonworld.weebly.com', port=80): Max retries exceeded with url: /uploads/1/8/7/3/18731590/3778695.jpg?304 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f031e7becf8>: Failed to establish a new connection: [Errno 110] Connection timed out',))

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
# download_images(path/file, dest, max_pics=20, max_workers=0)

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
path = Path("data/Lesson 2 Accordion")
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# accordion
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='192' class='' max='192', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [192/192 00:00<00:00]
#     </div>
# cannot identify image file '/home/paperspace/deep_learning_I/data/accordion/00000062.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/accordion/00000118.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/accordion/00000083.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/accordion/00000191.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/accordion/00000148.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/accordion/00000186.jpg'
# bayan
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='184' class='' max='184', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [184/184 00:00<00:00]
#     </div>
# cannot identify image file '/home/paperspace/deep_learning_I/data/bayan/00000167.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bayan/00000182.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bayan/00000111.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bayan/00000110.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bayan/00000160.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bayan/00000075.jpg'
# concertina
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='186' class='' max='186', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [186/186 00:00<00:00]
#     </div>
# cannot identify image file '/home/paperspace/deep_learning_I/data/concertina/00000001.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/concertina/00000195.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/concertina/00000003.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/concertina/00000049.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/concertina/00000058.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/concertina/00000007.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/concertina/00000008.jpg'
# bandoneon
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='184' class='' max='184', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [184/184 00:00<00:00]
#     </div>
# cannot identify image file '/home/paperspace/deep_learning_I/data/bandoneon/00000149.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bandoneon/00000087.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bandoneon/00000177.jpg'
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/PIL/Image.py:2655: UserWarning: image file could not be identified because WEBP support not installed
#   warnings.warn(message)
# cannot identify image file '/home/paperspace/deep_learning_I/data/bandoneon/00000147.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bandoneon/00000040.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bandoneon/00000060.jpg'
# cannot identify image file '/home/paperspace/deep_learning_I/data/bandoneon/00000093.jpg'

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=299, num_workers=4,padding_mode='zeros')
data.normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.train_ds
# Out:
# DatasetTfm(ImageClassificationDataset of len 516)

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['accordion', 'bandoneon', 'bayan', 'concertina'], 4, 516, 151)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='9', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-495233eaf2b4> in <module>
# ----> 1 learn.fit_one_cycle(4)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, **kwargs)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor,
#      21                                         pct_start=pct_start, **kwargs))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, **kwargs:Any):
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     160         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     161         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 162             callbacks=self.callbacks+callbacks)
#     163
#     164     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      92     except Exception as e:
#      93         exception = e
# ---> 94         raise e
#      95     finally: cb_handler.on_train_end(exception)
#      96
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      82             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      83                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 84                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      85                 if cb_handler.on_batch_end(loss): break
#      86
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      16     if not is_listy(xb): xb = [xb]
#      17     if not is_listy(yb): yb = [yb]
# ---> 18     out = model(*xb)
#      19     out = cb_handler.on_loss_begin(out)
#      20
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#      86
#      87         if self.downsample is not None:
# ---> 88             residual = self.downsample(x)
#      89
#      90         out += residual
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# RuntimeError: CUDA error: out of memory

# %%
learn.save('stage-2')

# %%
learn.load('stage-2')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(1, max_lr=1e-4)
# Out:
# Total time: 00:18
# epoch  train_loss  valid_loss  error_rate
# 1      0.787533    0.899066    0.344371    (00:18)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-aa7f7b70a42b> in <module>
# ----> 1 interp = ClassificationInterpretation.from_learner(learn)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/learner.py in from_learner(cls, learn, sigmoid, tta)
#      81     def from_learner(cls, learn:Learner, sigmoid:bool=None, tta=False):
#      82         "Create an instance of `ClassificationInterpretation`. `tta` indicates if we want to use Test Time Augmentation."
# ---> 83         preds = learn.TTA(with_loss=True) if tta else learn.get_preds(with_loss=True)
#      84         return cls(learn.data, *preds, sigmoid=sigmoid)
#      85
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in get_preds(self, is_test, with_loss, n_batch, pbar)
#     204         lf = self.loss_func if with_loss else None
#     205         return get_preds(self.model, self.data.holdout(is_test), cb_handler=CallbackHandler(self.callbacks),
# --> 206                          activ=_loss_func2activ(self.loss_func), loss_func=lf, n_batch=n_batch, pbar=pbar)
#     207
#     208     def pred_batch(self, is_test:bool=False, pbar:Optional[PBar]=None) -> List[Tensor]:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in get_preds(model, dl, pbar, cb_handler, activ, loss_func, n_batch)
#      36     "Tuple of predictions and targets, and optional losses (if `loss_func`) using `dl`, max batches `n_batch`."
#      37     res = [torch.cat(o).cpu() for o in
# ---> 38            zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#      39     if loss_func is not None: res.append(calc_loss(res[0], res[1], loss_func))
#      40     if activ is not None: res[0] = activ(res[0])
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in validate(model, dl, loss_func, cb_handler, pbar, average, n_batch)
#      47     with torch.no_grad():
#      48         val_losses,nums = [],[]
# ---> 49         for xb,yb in progress_bar(dl, parent=pbar, leave=(pbar is not None)):
#      50             if cb_handler: xb, yb = cb_handler.on_batch_begin(xb, yb, train=False)
#      51             val_losses.append(loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler))
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      63         self.update(0)
#      64         try:
# ---> 65             for i,o in enumerate(self._gen):
#      66                 yield o
#      67                 if self.auto_update: self.update(i+1)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_data.py in __iter__(self)
#      80     def __iter__(self):
#      81         "Process and returns items from `DataLoader`."
# ---> 82         for b in self.dl: yield self.proc_batch(b)
#      83
#      84     def one_batch(self)->Collection[Tensor]:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     334                 self.reorder_dict[idx] = batch
#     335                 continue
# --> 336             return self._process_next_batch(batch)
#     337
#     338     next = __next__  # Python 2 compatibility
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _process_next_batch(self, batch)
#     355         self._put_indices()
#     356         if isinstance(batch, ExceptionWrapper):
# --> 357             raise batch.exc_type(batch.exc_msg)
#     358         return batch
#     359
#
# FileNotFoundError: Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/data.py", line 219, in __getitem__
#     x,y = self.ds[idx]
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_data.py", line 21, in __getitem__
#     if self.item is None: return self._get_x(i),self._get_y(i)
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/data.py", line 73, in _get_x
#     def _get_x(self,i): return self.image_opener(self.x[i])
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/image.py", line 369, in open_image
#     x = PIL.Image.open(fn).convert('RGB')
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/PIL/Image.py", line 2609, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/home/paperspace/deep_learning_I/data/Lesson 2 Accordion/accordion/00000047.jpg'

# %%
interp.plot_confusion_matrix()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-45-ab4f144f3c10> in <module>
# ----> 1 interp.plot_confusion_matrix()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/learner.py in plot_confusion_matrix(self, normalize, title, cmap, norm_dec, slice_size, **kwargs)
#     113         "Plot the confusion matrix, passing `kawrgs` to `plt.figure`."
#     114         # This function is mainly copied from the sklearn docs
# --> 115         cm = self.confusion_matrix(slice_size=slice_size)
#     116         plt.figure(**kwargs)
#     117         plt.imshow(cm, interpolation='nearest', cmap=cmap)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/learner.py in confusion_matrix(self, slice_size)
#     105         cm = torch.zeros(self.data.c, self.data.c, dtype=x.dtype)
#     106         for pred_class_slice, y_true_slice in self._get_data_in_slices(slice_size or self.y_true.shape[0]):
# --> 107             cm_slice = ((pred_class_slice==x[:,None]) & (y_true_slice==x[:,None,None])).sum(2)
#     108             torch.add(cm, cm_slice, out=cm)
#     109         return to_np(cm)
#
# RuntimeError: sizes must be non-negative

# %%
interp.most_confused()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-06171ec66e30> in <module>
# ----> 1 interp.most_confused()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/learner.py in most_confused(self, min_val, slice_size)
#     132     def most_confused(self, min_val:int=1, slice_size:int=None)->Collection[Tuple[str,str,int]]:
#     133         "Sorted descending list of largest non-diagonal entries of confusion matrix"
# --> 134         cm = self.confusion_matrix(slice_size=slice_size)
#     135         np.fill_diagonal(cm, 0)
#     136         res = [(self.data.classes[i],self.data.classes[j],cm[i,j])
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/learner.py in confusion_matrix(self, slice_size)
#     105         cm = torch.zeros(self.data.c, self.data.c, dtype=x.dtype)
#     106         for pred_class_slice, y_true_slice in self._get_data_in_slices(slice_size or self.y_true.shape[0]):
# --> 107             cm_slice = ((pred_class_slice==x[:,None]) & (y_true_slice==x[:,None,None])).sum(2)
#     108             torch.add(cm, cm_slice, out=cm)
#     109         return to_np(cm)
#
# RuntimeError: sizes must be non-negative

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `FileDeleter` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.
#
# First we need to get the file paths from our top_losses. Here's a handy function that pulls out all our top_losses:

# %%
from fastai.widgets import *

losses,idxs = interp.top_losses()
top_loss_paths = data.valid_ds.x[idxs]

# %% [markdown]
# Now we can pass in these paths to our widget.

# %%
fd = FileDeleter(file_paths=top_loss_paths)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff…
# Button(button_style='primary', description='Confirm', style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Confirm' to delete flagged photos and keep the rest in that row. The `File_Deleter` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses`.

# %% [markdown]
# ## Putting your model in production

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
# fastai.defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img
# Out:
# Image (3, 272, 498)

# %%
classes = ['black', 'grizzly', 'teddys']
data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224, padding_mode='zeros').normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet34)
learn.load('stage-1')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'black'

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# 18     0.395686    0.255465    0.082418    (00:09)
# 19     0.373232    0.263469    0.080586    (00:09)
# 20     0.348988    0.258300    0.080586    (00:10)
# 21     0.324616    0.261346    0.080586    (00:09)
# 22     0.311310    0.236431    0.071429    (00:09)
# 23     0.328342    0.245841    0.069597    (00:10)
# 24     0.306411    0.235111    0.064103    (00:10)
# 25     0.289134    0.227465    0.069597    (00:09)
# 26     0.284814    0.226022    0.064103    (00:09)
# 27     0.268398    0.222791    0.067766    (00:09)
# 28     0.255431    0.227751    0.073260    (00:10)
# 29     0.240742    0.235949    0.071429    (00:09)
# 30     0.227140    0.225221    0.075092    (00:09)
# 31     0.213877    0.214789    0.069597    (00:09)
# 32     0.201631    0.209382    0.062271    (00:10)
# 33     0.189988    0.210684    0.065934    (00:09)
# 34     0.181293    0.214666    0.073260    (00:09)
# 35     0.184095    0.222575    0.073260    (00:09)
# 36     0.194615    0.229198    0.076923    (00:10)
# 37     0.186165    0.218206    0.075092    (00:09)
# 38     0.176623    0.207198    0.062271    (00:10)
# 39     0.166854    0.207256    0.065934    (00:10)
# 40     0.162692    0.206044    0.062271    (00:09)
