# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
import fastai
fastai.__version__
#!ls -alt
# Out:
# '1.0.18'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'black'
file = 'black.csv'

# %%
folder = 'teddys'
file = 'teddys.csv'

# %%
folder = 'grizzly'
file = 'grizzly.csv'

# %% [markdown]
# You will need to run this line once per each category.

# %%
path = Path('data/grizzly')
dest = path
dest.mkdir(parents=True, exist_ok=True)

# %%
path = Path('data')
path
# Out:
# PosixPath('data')

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['teddys','grizzly','black']

# %%
file
# Out:
# 'grizzly.csv'

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 01:48<00:00]
#     </div>
# Error http://stmedia.stimg.co/ctyp-blackbear-getty.jpg?w=800 'content-length'
# Error http://mediad.publicbroadcasting.net/p/wvtf/files/styles/x_large/public/201607/AP_608334627084.jpg 'content-length'
# Error http://mediad.publicbroadcasting.net/p/hppr/files/styles/medium/public/201805/800px-Black_Bear-27527.jpg 'content-length'
# Error http://mediad.publicbroadcasting.net/p/wxpr/files/styles/x_large/public/201712/American_Black_Bear_059.jpg 'content-length'
# Error http://mediad.publicbroadcasting.net/p/wusf/files/styles/medium/public/201504/black_bear_closeup_gary_langley.jpg 'content-length'
# Error http://mediad.publicbroadcasting.net/p/kalw/files/styles/medium/public/201708/blackbears.jpg 'content-length'
# Error http://mediad.publicbroadcasting.net/p/kunc/files/styles/medium/public/201710/black-bear-tim-nicholson.jpg 'content-length'
# Error https://static1.squarespace.com/static/54c7b65ae4b00cfd22a58f3b/t/59cae0e951a584b8e1100b28/1509114215404/_P1I4528.jpg HTTPSConnectionPool(host='static1.squarespace.com', port=443): Max retries exceeded with url: /static/54c7b65ae4b00cfd22a58f3b/t/59cae0e951a584b8e1100b28/1509114215404/_P1I4528.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fd6c926fcc0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# Error https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/e/6d/e6d15321-d728-50bf-aef0-489d2976edfb/5b272688eba5b.image.jpg?resize=1200%2C675 'content-length'
# Error https://geology.com/stories/13/bear-areas/black-bear.jpg HTTPSConnectionPool(host='geology.com', port=443): Max retries exceeded with url: /stories/13/bear-areas/black-bear.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fd6cad0ee80>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# Error https://media.gannett-cdn.com/5114477740001/5114477740001_5776416745001_5776405714001-vs.jpg?pubId=5114477740001&quality=10 HTTPSConnectionPool(host='media.gannett-cdn.com', port=443): Max retries exceeded with url: /5114477740001/5114477740001_5776416745001_5776405714001-vs.jpg?pubId=5114477740001&quality=10 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fd6d026ecf8>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# Error https://nature.mdc.mo.gov/sites/default/files/styles/centered_full/public/media/images/2012/03/33-04-2012.jpg?itok=w-He8-HN HTTPSConnectionPool(host='nature.mdc.mo.gov', port=443): Max retries exceeded with url: /sites/default/files/styles/centered_full/public/media/images/2012/03/33-04-2012.jpg?itok=w-He8-HN (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fd6c91f6518>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# Error http://mediad.publicbroadcasting.net/p/michigan/files/styles/x_large/public/201702/big-black-bear-detailed-ursus-americanus.jpg 'content-length'
# Error https://bloximages.chicago2.vip.townnews.com
# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
# download_images(path/file, dest, max_pics=20, max_workers=0)

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
path = Path("data")
for c in classes:
    print(c)
    verify_images(path/c/c, delete=True, max_workers=8)
# Out:
# teddys
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='182' class='' max='182', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [182/182 00:03<00:00]
#     </div>
# [Errno 21] Is a directory: '/home/paperspace/course-v3/nbs/dl1/data/teddys/teddys/.ipynb_checkpoints'
# grizzly
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='180' class='' max='180', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [180/180 00:03<00:00]
#     </div>
# [Errno 21] Is a directory: '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/.ipynb_checkpoints'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000018.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000007.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000045.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000089.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000107.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000042.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000046.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000168.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000118.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000069.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/grizzly/grizzly/00000154.jpg'
# black
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='182' class='' max='182', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [182/182 00:03<00:00]
#     </div>
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000149.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000181.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000005.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000132.jpg'
# [Errno 21] Is a directory: '/home/paperspace/course-v3/nbs/dl1/data/black/black/.ipynb_checkpoints'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000018.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000007.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000199.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000002.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000095.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000111.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000131.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000053.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000147.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000103.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000102.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000164.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000078.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000083.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000190.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000011.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000142.jpg'
# cannot identify image file '/home/paperspace/course-v3/nbs/dl1/data/black/black/00000157.jpg'

# %%
path
# Out:
# PosixPath('data')

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=299, num_workers=4, padding_mode='zeros')
data.normalize(imagenet_stats)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-5cc881419bd1> in <module>
#       1 np.random.seed(42)
#       2 data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
# ----> 3         ds_tfms=get_transforms(), size=299, num_workers=4, padding_mode='zeros')
#       4 data.normalize(imagenet_stats)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/data.py in from_folder(cls, path, train, valid, test, valid_pct, **kwargs)
#     278             train_ds = ImageClassificationDataset.from_folder(path/train)
#     279             datasets = [train_ds, ImageClassificationDataset.from_folder(path/valid, classes=train_ds.classes)]
# --> 280         else: datasets = ImageClassificationDataset.from_folder(path/train, valid_pct=valid_pct)
#     281
#     282         if test: datasets.append(ImageClassificationDataset.from_single_folder(
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/data.py in from_folder(cls, folder, classes, valid_pct, extensions)
#      93             extensions:Collection[str]=image_extensions)->Union['ImageClassificationDataset', List['ImageClassificationDataset']]:
#      94         "Dataset of `classes` labeled images in `folder`. Optional `valid_pct` split validation set."
# ---> 95         if classes is None: classes = [cls.name for cls in find_classes(folder)]
#      96
#      97         fns,labels,keep = [],[],{}
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/core.py in find_classes(folder)
#      66 def find_classes(folder:Path)->FilePathList:
#      67     "List of label subdirectories in imagenet-style `folder`."
# ---> 68     classes = [d for d in folder.iterdir()
#      69                if d.is_dir() and not d.name.startswith('.')]
#      70     assert(len(classes)>0)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/core.py in <listcomp>(.0)
#      66 def find_classes(folder:Path)->FilePathList:
#      67     "List of label subdirectories in imagenet-style `folder`."
# ---> 68     classes = [d for d in folder.iterdir()
#      69                if d.is_dir() and not d.name.startswith('.')]
#      70     assert(len(classes)>0)
#
# ~/anaconda3/envs/fastai/lib/python3.6/pathlib.py in iterdir(self)
#    1077         if self._closed:
#    1078             self._raise_closed()
# -> 1079         for name in self._accessor.listdir(self):
#    1080             if name in {'.', '..'}:
#    1081                 # Yielding a path object for these makes little sense
#
# ~/anaconda3/envs/fastai/lib/python3.6/pathlib.py in wrapped(pathobj, *args)
#     385         @functools.wraps(strfunc)
#     386         def wrapped(pathobj, *args):
# --> 387             return strfunc(str(pathobj), *args)
#     388         return staticmethod(wrapped)
#     389
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data'

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.train_ds
# Out:
# DatasetTfm(ImageClassificationDataset of len 393)

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
#!rm /home/paperspace/course-v3/nbs/dl1/data/teddys/teddys/00000020.jpg

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddys'], 3, 390, 114)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 01:09
# epoch  train_loss  valid_loss  error_rate
# 1      0.046996    0.063343    0.017391    (00:18)
# 2      0.106854    0.095029    0.026087    (00:18)
# 3      0.077119    0.112154    0.034783    (00:16)
# 4      0.063038    0.114832    0.034783    (00:16)

# %%
learn.save('stage-2')

# %%
learn.load('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(1, max_lr=3e-4)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      0.236394    0.293985    0.104348    (00:13)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-ab4f144f3c10> in <module>
# ----> 1 interp.plot_confusion_matrix()
#
# ~/course-v3/nbs/dl1/fastai/vision/learner.py in plot_confusion_matrix(self, normalize, title, cmap, norm_dec, slice_size, **kwargs)
#     113         "Plot the confusion matrix, passing `kawrgs` to `plt.figure`."
#     114         # This function is mainly copied from the sklearn docs
# --> 115         cm = self.confusion_matrix(slice_size=slice_size)
#     116         plt.figure(**kwargs)
#     117         plt.imshow(cm, interpolation='nearest', cmap=cmap)
#
# ~/course-v3/nbs/dl1/fastai/vision/learner.py in confusion_matrix(self, slice_size)
#     105         cm = torch.zeros(self.data.c, self.data.c, dtype=x.dtype)
#     106         for pred_class_slice, y_true_slice in self._get_data_in_slices(slice_size or self.y_true.shape[0]):
# --> 107             cm_slice = ((pred_class_slice==x[:,None]) & (y_true_slice==x[:,None,None])).sum(2)
#     108             torch.add(cm, cm_slice, out=cm)
#     109         return to_np(cm)
#
# RuntimeError: sizes must be non-negative

# %%
# %debug
# Out:
# > /home/paperspace/course-v3/nbs/dl1/fastai/vision/learner.py(107)confusion_matrix()
#     105         cm = torch.zeros(self.data.c, self.data.c, dtype=x.dtype)
#     106         for pred_class_slice, y_true_slice in self._get_data_in_slices(slice_size or self.y_true.shape[0]):
# --> 107             cm_slice = ((pred_class_slice==x[:,None]) & (y_true_slice==x[:,None,None])).sum(2)
#     108             torch.add(cm, cm_slice, out=cm)
#     109         return to_np(cm)
#
# ipdb> p y_true_slice
# tensor([], dtype=torch.int64)
# ipdb> p y_true.shape
# *** NameError: name 'y_true' is not defined
# ipdb> p self.y_true.shape
# torch.Size([114])
# ipdb> p cm_slice
# tensor([[37,  1,  0],
#         [ 1, 32,  0],
#         [ 0,  0, 43]])
# ipdb> p x
# tensor([0, 1, 2])

# %%
interp.plot_top_losses(4, figsize=(15,11))

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `FileDeleter` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.
#
# First we need to get the file paths from our top_losses. Here's a handy function that pulls out all our top_losses:

# %%
from fastai.widgets import *

losses,idxs = interp.top_losses()
top_loss_paths = data.valid_ds.x[idxs]

# %% [markdown]
# Now we can pass in these paths to our widget.

# %%
fd = FileDeleter(file_paths=top_loss_paths)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x…
# Button(button_style='primary', description='Confirm', style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Confirm' to delete flagged photos and keep the rest in that row. The `File_Deleter` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses`.

# %% [markdown]
# ## Putting your model in production

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
# fastai.defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img
# Out:
# Image (3, 272, 498)

# %%
classes = ['black', 'grizzly', 'teddys']
data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224, padding_mode='zeros').normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet34)
learn.load('stage-1')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'black'

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# 18     0.395686    0.255465    0.082418    (00:09)
# 19     0.373232    0.263469    0.080586    (00:09)
# 20     0.348988    0.258300    0.080586    (00:10)
# 21     0.324616    0.261346    0.080586    (00:09)
# 22     0.311310    0.236431    0.071429    (00:09)
# 23     0.328342    0.245841    0.069597    (00:10)
# 24     0.306411    0.235111    0.064103    (00:10)
# 25     0.289134    0.227465    0.069597    (00:09)
# 26     0.284814    0.226022    0.064103    (00:09)
# 27     0.268398    0.222791    0.067766    (00:09)
# 28     0.255431    0.227751    0.073260    (00:10)
# 29     0.240742    0.235949    0.071429    (00:09)
# 30     0.227140    0.225221    0.075092    (00:09)
# 31     0.213877    0.214789    0.069597    (00:09)
# 32     0.201631    0.209382    0.062271    (00:10)
# 33     0.189988    0.210684    0.065934    (00:09)
# 34     0.181293    0.214666    0.073260    (00:09)
# 35     0.184095    0.222575    0.073260    (00:09)
# 36     0.194615    0.229198    0.076923    (00:10)
# 37     0.186165    0.218206    0.075092    (00:09)
# 38     0.176623    0.207198    0.062271    (00:10)
# 39     0.166854    0.207256    0.065934    (00:10)
# 40     0.162692    0.206044    0.062271    (00:09)
